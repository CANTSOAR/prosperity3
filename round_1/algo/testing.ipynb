# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

os.chdir(os.path.abspath("/Users/dipalshah/Desktop/prosperity3"))

print("Working directory set to:", os.getcwd())

from tools import Plotter
# Out:
# Working directory set to: /Users/dipalshah/Desktop/prosperity3

# %%
p1 = pd.read_csv("round_1/data/prices_round_1_day_-2.csv", sep=";", index_col = "timestamp")
p2 = pd.read_csv("round_1/data/prices_round_1_day_-1.csv", sep=";", index_col = "timestamp")
p3 = pd.read_csv("round_1/data/prices_round_1_day_0.csv", sep=";", index_col = "timestamp")
t1 = pd.read_csv("round_1/data/trades_round_1_day_-2.csv", sep=";", index_col = "timestamp")
t2 = pd.read_csv("round_1/data/trades_round_1_day_-1.csv", sep=";", index_col = "timestamp")
t3 = pd.read_csv("round_1/data/trades_round_1_day_0.csv", sep=";", index_col = "timestamp")

# %%
p1
# Out:
#            day           product  bid_price_1  bid_volume_1  bid_price_2  \
# timestamp
# 0           -2  RAINFOREST_RESIN         9996             1       9995.0
# 0           -2              KELP         1998            26          NaN
# 0           -2         SQUID_INK         1998            26          NaN
# 100         -2         SQUID_INK         1999             5       1998.0
# 100         -2  RAINFOREST_RESIN        10000             5       9995.0
# ...        ...               ...          ...           ...          ...
# 999800      -2  RAINFOREST_RESIN         9996             1       9995.0
# 999800      -2              KELP         2026            26          NaN
# 999900      -2  RAINFOREST_RESIN         9996             2       9995.0
# 999900      -2              KELP         2027             4       2026.0
# 999900      -2         SQUID_INK         2003             4       2002.0
#
#            bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# timestamp
# 0                  25.0          NaN           NaN        10004             1
# 0                   NaN          NaN           NaN         2002            26
# 0                   NaN          NaN           NaN         2002            26
# 100                26.0          NaN           NaN         2001            20
# 100                20.0          NaN           NaN        10005            20
# ...                 ...          ...           ...          ...           ...
# 999800             25.0          NaN           NaN         9998             1
# 999800              NaN          NaN           NaN         2028             3
# 999900             30.0          NaN           NaN        10004             2
# 999900             32.0          NaN           NaN         2029            32
# 999900             32.0          NaN           NaN         2005            32
#
#            ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# timestamp
# 0              10005.0          25.0          NaN           NaN    10000.0
# 0                  NaN           NaN          NaN           NaN     2000.0
# 0                  NaN           NaN          NaN           NaN     2000.0
# 100                NaN           NaN          NaN           NaN     2000.0
# 100                NaN           NaN          NaN           NaN    10002.5
# ...                ...           ...          ...           ...        ...
# 999800         10002.0           9.0      10004.0           1.0     9997.0
# 999800          2030.0          26.0          NaN           NaN     2027.0
# 999900         10005.0          30.0          NaN           NaN    10000.0
# 999900             NaN           NaN          NaN           NaN     2028.0
# 999900             NaN           NaN          NaN           NaN     2004.0
#
#            profit_and_loss
# timestamp
# 0                      0.0
# 0                      0.0
# 0                      0.0
# 100                    0.0
# 100                    0.0
# ...                    ...
# 999800                 0.0
# 999800                 0.0
# 999900                 0.0
# 999900                 0.0
# 999900                 0.0
#
# [30000 rows x 16 columns]

# %%
t1
# Out:
#            buyer  seller            symbol   currency   price  quantity
# timestamp
# 0            NaN     NaN              KELP  SEASHELLS  2002.0         1
# 0            NaN     NaN  RAINFOREST_RESIN  SEASHELLS  9996.0         1
# 0            NaN     NaN  RAINFOREST_RESIN  SEASHELLS  9996.0         1
# 0            NaN     NaN         SQUID_INK  SEASHELLS  2002.0         1
# 100          NaN     NaN              KELP  SEASHELLS  2002.0         6
# ...          ...     ...               ...        ...     ...       ...
# 998900       NaN     NaN              KELP  SEASHELLS  2029.0         1
# 998900       NaN     NaN         SQUID_INK  SEASHELLS  2001.0         1
# 999000       NaN     NaN              KELP  SEASHELLS  2030.0         9
# 999000       NaN     NaN         SQUID_INK  SEASHELLS  2002.0         9
# 999800       NaN     NaN  RAINFOREST_RESIN  SEASHELLS  9998.0         1
#
# [8398 rows x 6 columns]

# %%
Plotter.plot_prices_simple(p1, "KELP")

# %%
Plotter.plot_prices_full(p1, "KELP")
